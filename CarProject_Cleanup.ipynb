# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Manju410/MLPractice/main/data/Cardetails.csv')
df.head()
# Out:
#                            name  year  ...                    torque  seats
# 0        Maruti Swift Dzire VDI  2014  ...            190Nm@ 2000rpm    5.0
# 1  Skoda Rapid 1.5 TDI Ambition  2014  ...       250Nm@ 1500-2500rpm    5.0
# 2      Honda City 2017-2020 EXi  2006  ...     12.7@ 2,700(kgm@ rpm)    5.0
# 3     Hyundai i20 Sportz Diesel  2010  ...  22.4 kgm at 1750-2750rpm    5.0
# 4        Maruti Swift VXI BSIII  2007  ...     11.5@ 4,500(kgm@ rpm)    5.0
#
# [5 rows x 13 columns]

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.name.unique()
# Out:
# array(['Maruti Swift Dzire VDI', 'Skoda Rapid 1.5 TDI Ambition',
#        'Honda City 2017-2020 EXi', ..., 'Tata Nexon 1.5 Revotorq XT',
#        'Ford Freestyle Titanium Plus Diesel BSIV',
#        'Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV'], dtype=object)

# %%
x='Maruti Swift Dzire VDI'

# %%
x.split(' ')[0]
# Out:
# 'Maruti'

# %%
x.split(' ')[1]
# Out:
# 'Swift'

# %%
#[x.split(' ')[0] for x in df['name']]
df['name'].apply(lambda x: x.split(' ')[1])[:5]
# Out:
# 0    Swift
# 1    Rapid
# 2     City
# 3      i20
# 4    Swift
# Name: name, dtype: object

# %%
df.name.str.split(' ').str[:2].str.join(' ')[:5]
# Out:
# 0    Maruti Swift
# 1     Skoda Rapid
# 2      Honda City
# 3     Hyundai i20
# 4    Maruti Swift
# Name: name, dtype: object

# %%
import re

# %%
def carname(name):
  if re.match("Maruti",name):return "Maruti"
  elif re.match("Honda",name): return "Honda"
  elif re.match("Toyota",name): return "Toyota"
  elif re.match("Mercedes",name): return "Mercedes"
  elif re.match("Tata",name): return "Tata"
  elif re.match("Jeep",name): return "Jeep"
  elif re.match("Hyundai",name): return "Hyundai"
  elif re.match("Fiat",name): return "Fiat"
  elif re.match("Chevrolet",name): return "Chevrolet"
  elif re.match("Mahindra",name): return "Mahindra"
  elif re.match("Skoda",name): return "Skoda"
  elif re.match("Renault",name): return "Renault"
  elif re.match("Ford",name): return "Ford"
  else: return "Other Cars"

# %%
df['name'] = df.name.apply(carname)

# %%
len(df.name.unique())
# Out:
# 14

# %%
df.name.value_counts()
# Out:
# Maruti        2448
# Hyundai       1415
# Mahindra       772
# Tata           734
# Other Cars     712
# Toyota         488
# Honda          467
# Ford           397
# Chevrolet      230
# Renault        228
# Skoda          105
# Mercedes        54
# Fiat            47
# Jeep            31
# Name: name, dtype: int64

# %%
df.year.unique()
# Out:
# array([2014, 2006, 2010, 2007, 2017, 2001, 2011, 2013, 2005, 2009, 2016,
#        2012, 2002, 2015, 2018, 2003, 2019, 2008, 2020, 1999, 2000, 1983,
#        2004, 1996, 1994, 1995, 1998, 1997, 1991])

# %%
df.fuel.unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
df.seller_type.unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
df.transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df.owner.unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
from numpy.core.numeric import NaN
def integer(val):
  z = re.match("[0-9.]+",str(val));
  if z: return str(z.group())
  else: return NaN

# %%
df.mileage = df.mileage.apply(integer)

# %%
df['mileage'] = df['mileage'].astype(float)

# %%
df.mileage.fillna(df.mileage.mean(),inplace=True)

# %%
df.engine = df.engine.apply(integer)

# %%
df.engine.fillna(df.engine.value_counts().index[0],inplace=True)

# %%
df['engine'] = df['engine'].astype(int)

# %%
df.engine.unique()
# Out:
# array([1248, 1498, 1497, 1396, 1298, 1197, 1061,  796, 1364, 1399, 1461,
#         993, 1198, 1199,  998, 1591, 2179, 1368, 2982, 2494, 2143, 2477,
#        1462, 2755, 1968, 1798, 1196, 1373, 1598, 1998, 1086, 1194, 1172,
#        1405, 1582,  999, 2487, 1999, 3604, 2987, 1995, 1451, 1969, 2967,
#        2497, 1797, 1991, 2362, 1493, 1599, 1341, 1794,  799, 1193, 2696,
#        1495, 1186, 1047, 2498, 2956, 2523, 1120,  624, 1496, 1984, 2354,
#         814,  793, 1799,  936, 1956, 1997, 1499, 1948, 2997, 2489, 2499,
#        2609, 2953, 1150, 1994, 1388, 1527, 2199,  995, 2993, 1586, 1390,
#         909, 2393, 3198, 1339, 2835, 2092, 1595, 2496, 1596, 1597, 2596,
#        2148, 1299, 1590, 2231, 2694, 2200, 1795, 1896, 1796, 1422, 1489,
#        2359, 2197, 2999, 1781, 2650, 1343, 2446, 3498, 2198, 2776, 1950])

# %%
df.engine.value_counts().index[0]
# Out:
# 1248

# %%
df.max_power = df.max_power.apply(integer)

# %%
df['max_power'] = df['max_power'].astype(float)

# %%
df.max_power.fillna(df.max_power.mean(),inplace=True)

# %%
df.max_power.unique()
# Out:
# array([ 74.        , 103.52      ,  78.        ,  90.        ,
#         88.2       ,  81.86      ,  57.5       ,  37.        ,
#         67.1       ,  68.1       , 108.45      ,  60.        ,
#         73.9       ,  91.51791898,  67.        ,  82.        ,
#         88.5       ,  46.3       ,  88.73      ,  64.1       ,
#         98.6       ,  88.8       ,  83.81      ,  83.1       ,
#         47.3       ,  73.8       ,  34.2       ,  35.        ,
#         81.83      ,  40.3       , 121.3       , 138.03      ,
#        160.77      , 117.3       , 116.3       ,  83.14      ,
#         67.05      , 168.5       , 100.        , 120.7       ,
#         98.63      , 175.56      , 103.25      , 171.5       ,
#        100.6       , 174.33      , 187.74      , 170.        ,
#         78.9       ,  88.76      ,  86.8       , 108.495     ,
#        108.62      ,  93.7       , 103.6       ,  98.59      ,
#        189.        ,  67.04      ,  68.05      ,  58.2       ,
#         82.85      ,  81.8       ,  73.        , 120.        ,
#         94.68      , 160.        ,  65.        , 155.        ,
#         69.01      , 126.32      , 138.1       ,  83.8       ,
#        126.2       ,  98.96      ,  62.1       ,  86.7       ,
#        188.        , 214.56      , 177.        , 280.        ,
#        148.31      , 254.79      , 190.        , 177.46      ,
#        204.        , 141.        , 117.6       , 241.4       ,
#        282.        , 150.        , 147.5       , 108.5       ,
#        103.5       , 183.        , 181.04      , 157.7       ,
#        164.7       ,  91.1       , 400.        ,  68.        ,
#         75.        ,  85.8       ,  87.2       ,  53.        ,
#        118.        , 103.2       ,  83.        ,  84.        ,
#         58.16      , 147.94      ,  74.02      ,  53.3       ,
#         80.        ,  88.7       ,  97.7       , 121.36      ,
#        162.        , 140.        ,  94.        , 100.57      ,
#         82.9       ,  83.11      ,  70.        , 153.86      ,
#        121.        , 126.3       ,  73.97      , 171.        ,
#         69.        ,  99.6       , 102.        , 105.        ,
#         63.        ,  79.4       ,  97.9       ,  63.1       ,
#         66.1       , 110.        , 174.5       ,  53.26      ,
#         73.75      ,  67.06      ,  64.08      ,  37.5       ,
#        189.3       , 158.8       ,  61.7       ,  55.2       ,
#         71.01      ,  73.74      , 147.9       ,  71.        ,
#         77.        , 121.4       , 113.4       ,  47.        ,
#        130.        ,  57.6       , 138.        ,  52.8       ,
#         53.64      ,  53.5       ,  76.8       ,  82.4       ,
#        113.42      ,  76.        ,  84.8       ,   0.        ,
#         56.3       , 218.        , 112.        ,  92.        ,
#        105.5       , 169.        ,  95.        ,  72.4       ,
#        115.        , 152.        ,  91.2       , 156.        ,
#         74.9       ,  62.        , 105.3       ,  73.94      ,
#         85.        , 118.3       ,  72.        , 147.51      ,
#         58.        ,  64.        , 126.24      ,  76.9       ,
#        194.3       ,  99.23      ,  89.84      , 123.7       ,
#        118.35      ,  99.        , 241.        , 136.        ,
#        261.4       , 104.68      ,  37.48      , 104.        ,
#         63.12      ,  91.7       , 102.5       , 177.6       ,
#         45.        , 123.37      , 147.8       , 184.        ,
#         84.48      ,  68.07      ,  74.96      , 167.6       ,
#        152.87      , 112.2       ,  83.83      , 197.        ,
#        110.4       , 104.55      , 103.        , 103.3       ,
#         66.        , 108.6       , 165.        , 163.7       ,
#        116.9       ,  94.93      , 127.        , 198.5       ,
#        179.5       , 120.69      , 121.31      , 138.08      ,
#        187.7       ,  80.8       ,  86.79      ,  93.87      ,
#        116.6       , 143.        ,  92.7       ,  88.        ,
#         58.33      ,  78.8       ,  64.4       , 125.        ,
#        139.01      , 254.8       , 181.        , 258.        ,
#         55.23      , 270.9       , 265.        , 157.75      ,
#        101.        , 186.        , 187.4       , 224.        ,
#         64.9       , 148.        ,  35.5       ,  89.75      ,
#         32.8       ,  91.72      , 106.        ,  98.97      ,
#         66.6       ,  86.        ,  65.3       ,  98.82      ,
#        198.25      ,  38.        , 142.        , 132.        ,
#        174.57      , 178.        , 163.2       , 203.2       ,
#        177.5       , 175.        ,  57.        ,  80.84      ,
#         68.4       , 167.67      , 170.63      ,  52.        ,
#        149.5       ,  48.21      , 201.1       , 100.5       ,
#        144.        , 194.4       , 168.7       , 104.5       ,
#        103.26      , 116.4       ,  98.79      ,  80.9       ,
#         58.3       , 272.        , 235.        , 167.62      ,
#        170.3       , 139.46      , 158.        , 110.5       ,
#         82.5       , 141.1       ,  38.4       , 197.2       ,
#        161.        , 194.        , 122.4       , 134.1       ,
#         60.2       , 134.        , 203.        , 135.1       ])

# %%
df.torque[:5]
# Out:
# 0              190Nm@ 2000rpm
# 1         250Nm@ 1500-2500rpm
# 2       12.7@ 2,700(kgm@ rpm)
# 3    22.4 kgm at 1750-2750rpm
# 4       11.5@ 4,500(kgm@ rpm)
# Name: torque, dtype: object

# %%
integer("190Nm@ 2000rpm")
# Out:
# '190'

# %%
df.torque = df.torque.apply(integer)

# %%
df['torque'] = df['torque'].astype(float)

# %%
df.torque.fillna(df.torque.mean(),inplace=True)

# %%
df.torque.unique()
# Out:
# array([190.        , 250.        ,  12.7       ,  22.4       ,
#         11.5       , 113.75      ,   7.8       ,  59.        ,
#        170.        , 160.        , 248.        ,  78.        ,
#        168.29414116,  84.        , 115.        , 200.        ,
#         62.        , 219.7       , 114.        ,  69.        ,
#        172.5       ,   6.1       , 114.7       ,  60.        ,
#         90.        , 151.        , 104.        , 320.        ,
#        145.        , 146.        , 343.        , 400.        ,
#        138.        , 360.        , 380.        , 173.        ,
#        111.7       , 219.6       , 112.        , 130.        ,
#        205.        , 280.        ,  99.04      ,  77.        ,
#        110.        , 153.        , 113.7       , 113.        ,
#        101.        , 290.        , 120.        ,  96.        ,
#        135.        , 259.8       , 259.9       ,  91.        ,
#         96.1       , 109.        , 202.        , 430.        ,
#        347.        , 382.        , 620.        , 500.        ,
#        550.        , 490.        , 177.5       , 300.        ,
#        260.        , 213.        , 224.        , 640.        ,
#         95.        ,  13.1       ,  71.        ,  14.9       ,
#        117.        ,  72.        ,  11.4       , 140.        ,
#        134.        , 150.        , 340.        , 240.        ,
#        330.        ,  12.5       , 111.8       ,  11.8       ,
#        135.4       , 190.25      ,  20.4       , 247.        ,
#        223.        , 180.        , 195.        , 154.9       ,
#        114.73      , 108.        , 190.24      , 420.        ,
#        100.        ,  51.        , 132.        , 350.        ,
#        218.        ,  24.        ,  13.5       ,  85.        ,
#         74.5       , 180.4       , 230.        , 219.66      ,
#        245.        , 204.        ,  14.3       , 125.        ,
#        172.        , 102.        ,   8.5       , 106.5       ,
#        108.5       , 144.15      ,  99.        , 142.5       ,
#        196.        ,   9.8       , 209.        , 220.        ,
#         48.        , 171.        , 277.5       , 215.        ,
#         13.        , 263.7       ,  25.5       ,  16.3       ,
#         94.14      ,  12.        ,  16.        , 789.        ,
#        259.87      , 436.39      , 182.5       ,  90.3       ,
#        305.        , 540.        , 327.        , 450.        ,
#         19.        ,   9.2       , 148.        , 116.        ,
#        222.        , 135.3       ,  98.        , 402.        ,
#         99.07      , 210.        ,  32.1       ,  25.        ,
#        197.        , 136.3       , 470.        ,  11.        ,
#        142.        , 123.        , 510.        , 292.        ,
#         20.        ,  46.5       ,  15.        , 136.        ,
#        228.        , 149.        , 187.        ,   8.6       ,
#         42.        , 225.        ,  28.3       , 259.88      ,
#        580.        , 127.        , 132.3       ,  10.7       ,
#        124.6       , 219.9       , 420.7       , 424.        ,
#         99.8       ,  11.2       ,  16.1       , 321.        ,
#        619.        , 560.        , 600.        ,  16.6       ,
#         33.7       , 285.        , 226.        , 155.        ,
#        103.        , 175.        ,  72.9       ,  57.        ,
#         10.4       , 128.        , 131.        , 185.        ,
#         12.4       , 176.        ,  24.5       ,  22.9       ,
#        121.        , 106.        ,  21.4       ,  23.6       ,
#         11.3       ,  35.7       ,   6.        ,  13.9       ,
#        113.8       ,  18.        ,  83.        , 124.5       ,
#        171.6       ,   5.7       ,  88.4       ,  36.6       ,
#          4.8       , 355.        , 119.        , 410.        ,
#        174.        ,  99.1       , 385.        ,  53.        ,
#        124.        ,  17.5       , 159.8       , 333.        ,
#         33.        ,  10.2       , 480.        , 250.06      ,
#        436.4       ])

# %%
df.seats.unique()
# Out:
# array([ 5.,  4., nan,  7.,  8.,  6.,  9., 10., 14.,  2.])

# %%
df.seats.fillna(df.seats.value_counts().index[0],inplace=True)

# %%
df.isna().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        8128 non-null   float64
#  9   engine         8128 non-null   int64
#  10  max_power      8128 non-null   float64
#  11  torque         8128 non-null   float64
#  12  seats          8128 non-null   float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 825.6+ KB

# %%
df.head()
# Out:
#       name  year  selling_price  km_driven  ... engine max_power torque seats
# 0   Maruti  2014         450000     145500  ...   1248     74.00  190.0   5.0
# 1    Skoda  2014         370000     120000  ...   1498    103.52  250.0   5.0
# 2    Honda  2006         158000     140000  ...   1497     78.00   12.7   5.0
# 3  Hyundai  2010         225000     127000  ...   1396     90.00   22.4   5.0
# 4   Maruti  2007         130000     120000  ...   1298     88.20   11.5   5.0
#
# [5 rows x 13 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encod = LabelEncoder()

# %%
df.name = label_encod.fit_transform(df.name)

# %%
df.name.unique()
# Out:
# array([ 7, 11,  3,  4, 13,  2, 10,  6, 12,  0,  1,  9,  5,  8])

# %%
cat_col = df.dtypes[df.dtypes =='object'].index.tolist()
cat_col
# Out:
# ['fuel', 'seller_type', 'transmission', 'owner']

# %%
def catconvert(df,catcol):
  continueval = []
  continueval.append(df)
  for col in catcol:
    tempdf = pd.get_dummies(df[col],prefix=col)
    continueval.append(tempdf)

  dffinal = pd.concat(continueval,axis=1)
  dffinal.drop(columns=catcol, axis=1, inplace=True)  
  return dffinal

# %%
finaldf = catconvert(df,cat_col)
finaldf.head()
# Out:
#    name  year  ...  owner_Test Drive Car  owner_Third Owner
# 0     7  2014  ...                     0                  0
# 1    11  2014  ...                     0                  0
# 2     3  2006  ...                     0                  1
# 3     4  2010  ...                     0                  0
# 4     7  2007  ...                     0                  0
#
# [5 rows x 23 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
finaldf.to_csv('/content/drive/MyDrive/CarDetails_Cleanup.csv', index=False)
