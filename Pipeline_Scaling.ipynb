# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %%
df.shape
# Out:
# (344, 7)

# %%
target = 'body_mass_g'
X= df.drop(target,axis=1)
y= df.loc[:,target]

# %%
X.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# sex                  11
# dtype: int64

# %%
y.isna().sum()
# Out:
# 2

# %% [markdown]
# - To avoid hassles of missing target values lets forcefully impute target with its mean value
# - This is only for learning purpose and should never be done in new world

# %%
y.fillna(y.mean(),inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=345)
X_train.shape,X_test.shape
# Out:
# ((258, 6), (86, 6))

# %%
X_train.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       1
# bill_depth_mm        1
# flipper_length_mm    1
# sex                  7
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       1
# bill_depth_mm        1
# flipper_length_mm    1
# sex                  4
# dtype: int64

# %% [markdown]
# # Selecting numerical and categorical columns

# %%
from sklearn.compose import make_column_selector

# %%
num_cols = make_column_selector(dtype_exclude=object)
cat_cols = make_column_selector(dtype_include=object)

# %% [markdown]
# # Impute missing values

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
imp_mean = SimpleImputer(strategy='mean')

# %%
imp_mediean = SimpleImputer(strategy='median')

# %%
imp_mode = SimpleImputer(strategy='most_frequent')
one_hot = OneHotEncoder()

# %%
col_trans = make_column_transformer(
    (make_pipeline(imp_mean), num_cols),
    (make_pipeline(imp_mode,one_hot), cat_cols),
    remainder='passthrough'
)

# %% [markdown]
# # Build the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
std_scaler = StandardScaler()

# %%
lr_model = LinearRegression()

# %%
pipe = make_pipeline(col_trans,std_scaler,lr_model)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f40629f1c90>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f40629f1510>)])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
pipe.score(X_test,y_test)
# Out:
# 0.8776148173594256

# %%
X_train.head()
# Out:
#        species  island  ...  flipper_length_mm     sex
# 160  Chinstrap   Dream  ...              195.0  Female
# 263     Gentoo  Biscoe  ...              216.0    Male
# 100     Adelie  Biscoe  ...              192.0  Female
# 65      Adelie  Biscoe  ...              192.0    Male
# 158  Chinstrap   Dream  ...              178.0  Female
#
# [5 rows x 6 columns]

# %%
from sklearn import set_config

# %%
set_config(display='diagram')
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f40629f1c90>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f40629f1510>)])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
