# %% [markdown]
# # Real Estate Price Prediction
#
# User want to know the price of the house of unit area depends on 6 parameter as mentioned below.
# Transaction date, house age, distance to the nearest MRT station, number of convenience stores in the living circle, geographic coordinate latitude, geographic coordinate longitude.

# %% [markdown]
# - Attribute Information:
#
# - The inputs are as follows
# - X1=the transaction date (for example, 2013.250=2013 March, 2013.500=2013 June, etc.)
# - X2=the house age (unit: year)
# - X3=the distance to the nearest MRT station (unit: meter)
# - X4=the number of convenience stores in the living circle on foot (integer)
# - X5=the geographic coordinate, latitude. (unit: degree)
# - X6=the geographic coordinate, longitude. (unit: degree)
#
# The output is as follow
# Y= house price of unit area (10000 New Taiwan Dollar/Ping, where Ping is a local unit, 1 Ping = 3.3 meter squared)

# %% [markdown]
# # Importing required libraries for the project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - Loading real estate dataset from git hub account

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Realdf = pd.read_csv('https://raw.githubusercontent.com/Manju410/MLPractice/main/Real_Estate_Price_Prediction/RealEstatCleanUp.csv')
Realdf = pd.read_csv('/content/drive/MyDrive/RealEstatCleanUp.csv')

# %%
Realdf.head()
# Out:
#    X1 transaction date  X2 house age  ...  X6 longitude  Y house price of unit area
# 0               734808          32.0  ...     121.54024                        37.9
# 1               734808          19.5  ...     121.53951                        42.2
# 2               735050          13.3  ...     121.54391                        47.3
# 3               735020          13.3  ...     121.54391                        54.8
# 4               734777           5.0  ...     121.54245                        43.1
#
# [5 rows x 7 columns]

# %% [markdown]
# - Number of rows and columns in the dataset

# %%
Realdf.shape
# Out:
# (414, 7)

# %% [markdown]
# - There are 414 rows and 8 columns in the above dataset

# %% [markdown]
# - Information about dataset like datatype,count etc

# %%
Realdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   X1 transaction date                     414 non-null    int64
#  1   X2 house age                            414 non-null    float64
#  2   X3 distance to the nearest MRT station  414 non-null    float64
#  3   X4 number of convenience stores         414 non-null    int64
#  4   X5 latitude                             414 non-null    float64
#  5   X6 longitude                            414 non-null    float64
#  6   Y house price of unit area              414 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 22.8 KB

# %% [markdown]
# # Summary of above output
# - Above dataset contains 8 columns.
# - Two columns are integer datatype and Six columns are float datatype.
# - Above dataset doesnot have any null values or empty values.
# - Above dataset have 414 etries total

# %% [markdown]
# - Extract Train Test Dataset

# %% [markdown]
# - -1 = except last column( house price of unit area) loading all rows and columns to X variable

# %%
X = Realdf.iloc[:,:-1]
y = Realdf['Y house price of unit area'].values.reshape(-1,1)

# %% [markdown]
# - Converting y values to 2 dimensional array

# %%
X.shape,y.shape
# Out:
# ((414, 6), (414, 1))

# %%
X.head()
# Out:
#    X1 transaction date  X2 house age  ...  X5 latitude  X6 longitude
# 0               734808          32.0  ...     24.98298     121.54024
# 1               734808          19.5  ...     24.98034     121.53951
# 2               735050          13.3  ...     24.98746     121.54391
# 3               735020          13.3  ...     24.98746     121.54391
# 4               734777           5.0  ...     24.97937     121.54245
#
# [5 rows x 6 columns]

# %% [markdown]
# # Spliting data to train and test lists
#
# - test size =0.25 : Assigning 25% of dataset to test and 75% of dataset to train.
# - random state : it will assign same set of rows to every batch to test the module.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=1234)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((310, 6), (104, 6), (310, 1), (104, 1))

# %% [markdown]
# # Lets Change Distance from meter to Kilometers

# %%
X_train1 = X_train.copy()

# %%
X_train1[X_train1.columns[2]] = X_train1[X_train1.columns[2]]/1000
X_train1.head()
# Out:
#      X1 transaction date  X2 house age  ...  X5 latitude  X6 longitude
# 268               734989          17.2  ...     24.97937     121.54245
# 337               734777          31.3  ...     24.96871     121.54651
# 36                734808          14.7  ...     24.96386     121.51458
# 351               734777           4.0  ...     24.96324     121.51241
# 278               734747           0.0  ...     24.95618     121.53844
#
# [5 rows x 6 columns]

# %%
X_test1 = X_test.copy()
X_test1[X_test1.columns[2]] = X_test1[X_test1.columns[2]]/1000
X_test1.head()
# Out:
#      X1 transaction date  X2 house age  ...  X5 latitude  X6 longitude
# 101               734777          12.7  ...     24.97371     121.52984
# 181               734900          11.6  ...     24.98489     121.54121
# 64                734959          17.5  ...     24.96305     121.54915
# 149               734716          34.9  ...     24.97349     121.54245
# 270               734959          10.8  ...     24.97460     121.53046
#
# [5 rows x 6 columns]

# %% [markdown]
# # KNN Algorithm

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn.metrics import mean_squared_error

# %%
model = KNeighborsRegressor()

# %%
model.fit(X_train1,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
print('\nThe number of neighbors used to predict the target : ',model.n_neighbors)
# Out:
# The number of neighbors used to predict the target :  5

# %% [markdown]
# - default n_neighbors selected as 5 by model

# %%
predict_train = model.predict(X_train1)
predict_train[:5]
# Out:
# array([[44.94],
#        [32.84],
#        [26.24],
#        [33.54],
#        [47.18]])

# %% [markdown]
# - Predicting for training dataset. X_train1 is scacle down value

# %%
accuracy_train = mean_squared_error(y_train,predict_train)
accuracy_train
# Out:
# 80.42807354838709

# %%
predict_test = model.predict(X_test1)
predict_test[:5]
# Out:
# array([[31.3 ],
#        [33.  ],
#        [27.58],
#        [43.16],
#        [39.22]])

# %%
accuracy_test = mean_squared_error(y_test,predict_test)
accuracy_test
# Out:
# 181.63773461538466

# %%
from sklearn import neighbors
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# - checking for different K value what is the error

# %%
rmse_val = [] #to store rmse values for different k
for K in range(30):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(X_train1, y_train)  #fit the model
    pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(y_test,pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 28.592143555125823
# RMSE value for k=  2 is: 26.678329130444205
# RMSE value for k=  3 is: 25.757719571448238
# RMSE value for k=  4 is: 25.08944527930175
# RMSE value for k=  5 is: 24.341114869227397
# RMSE value for k=  6 is: 23.425565650980044
# RMSE value for k=  7 is: 22.899958911139297
# RMSE value for k=  8 is: 22.294844272382967
# RMSE value for k=  9 is: 21.890801171403616
# RMSE value for k=  10 is: 21.512999200840976
# RMSE value for k=  11 is: 21.209705130051923
# RMSE value for k=  12 is: 20.877410552257707
# RMSE value for k=  13 is: 20.570588072547473
# RMSE value for k=  14 is: 20.15643798514069
# RMSE value for k=  15 is: 19.65972765459866
# RMSE value for k=  16 is: 19.114054762612486
# RMSE value for k=  17 is: 18.773270875401344
# RMSE value for k=  18 is: 18.50242809423242
# RMSE value for k=  19 is: 18.280114096550676
# RMSE value for k=  20 is: 17.933915904326685
# RMSE value for k=  21 is: 17.780862755345634
# RMSE value for k=  22 is: 17.640707247986246
# RMSE value for k=  23 is: 17.336887084290762
# RMSE value for k=  24 is: 17.219596056470763
# RMSE value for k=  25 is: 17.081083626226814
# RMSE value for k=  26 is: 16.944274504849005
# RMSE value for k=  27 is: 16.75103973565187
# RMSE value for k=  28 is: 16.619107529778553
# RMSE value for k=  29 is: 16.45852416874135
# RMSE value for k=  30 is: 16.317489182013517

# %%
r2_val = [] #to store rmse values for different k
k_val=[]
for K in range(30):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(X_train1, y_train)  #fit the model
    pred=model.predict(X_test) #make prediction on test set
    error = model.score(X_test1,y_test)
    r2_val.append(error) #store rmse values
    k_val.append(K) #store rmse values
    print('R2 value for k= ' , K , 'is:', error)
# Out:
# R2 value for k=  1 is: 0.029537294547910875
# R2 value for k=  2 is: 0.08277940668624362
# R2 value for k=  3 is: 0.07355581464368766
# R2 value for k=  4 is: 0.12115298642047902
# R2 value for k=  5 is: 0.14506294969523215
# R2 value for k=  6 is: 0.14151618398857901
# R2 value for k=  7 is: 0.11969734233537233
# R2 value for k=  8 is: 0.06768711622904067
# R2 value for k=  9 is: 0.06974383386929506
# R2 value for k=  10 is: 0.02913650386395716
# R2 value for k=  11 is: 0.05484257250652358
# R2 value for k=  12 is: 0.06534158766870157
# R2 value for k=  13 is: 0.06990542456278204
# R2 value for k=  14 is: 0.08400105686298498
# R2 value for k=  15 is: 0.06406394865581055
# R2 value for k=  16 is: 0.042772689108796724
# R2 value for k=  17 is: 0.033990679927453527
# R2 value for k=  18 is: 0.03784695430172835
# R2 value for k=  19 is: 0.03834692060043299
# R2 value for k=  20 is: 0.05634139293580409
# R2 value for k=  21 is: 0.048347669959506685
# R2 value for k=  22 is: 0.045296814002830255
# R2 value for k=  23 is: 0.04506260608702228
# R2 value for k=  24 is: 0.044798045091868244
# R2 value for k=  25 is: 0.035732973163733805
# R2 value for k=  26 is: 0.043359848149081226
# R2 value for k=  27 is: 0.0481573869103854
# R2 value for k=  28 is: 0.0545001969055825
# R2 value for k=  29 is: 0.07150233207789769
# R2 value for k=  30 is: 0.0757839738558147

# %% [markdown]
# - as we see in above k values output its decreasing simultaneously while increasing k value

# %%
plt.plot(k_val,r2_val)

# %%
max(zip(r2_val, k_val))
# Out:
# (0.14506294969523215, 5)

# %%
#plotting the rmse values against k values
curve = pd.DataFrame(rmse_val) #elbow curve 
curve.plot()

# %% [markdown]
# - getting best k value by GridsearchCV technique

# %%
from sklearn.model_selection import GridSearchCV
params = {'n_neighbors':[2,3,4,5,6,7,8,9]}

knn = neighbors.KNeighborsRegressor()

model = GridSearchCV(knn, params, cv=5)
model.fit(X_train1,y_train)
model.best_params_
model.scorer_
model.
# Out:
# <function sklearn.metrics._scorer._passthrough_scorer>

# %%
X_train1.index[:10]
# Out:
# Int64Index([268, 337, 36, 351, 278, 200, 118, 203, 218, 245], dtype='int64')

# %%
X_test1.index[:10]
# Out:
# Int64Index([101, 181, 64, 149, 270, 92, 44, 404, 287, 74], dtype='int64')

# %% [markdown]
# # Linear Regression Model
#
# - Due to predict price of house which is continuous variable we are using Linear Regression model to predict the house price.

# %%
from sklearn.linear_model import LinearRegression

# %%
lrmodel = LinearRegression()
lrmodel.fit(X_train1,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# - Checking intercept and slope for the dataset

# %%
np.get_printoptions()
# Out:
# {'edgeitems': 3,
#  'floatmode': 'maxprec',
#  'formatter': None,
#  'infstr': 'inf',
#  'legacy': False,
#  'linewidth': 75,
#  'nanstr': 'nan',
#  'precision': 8,
#  'sign': '-',
#  'suppress': False,
#  'threshold': 1000}

# %% [markdown]
# - Checking co_efficient and intercept values from linear regression model.

# %%
c = lrmodel.intercept_
m = lrmodel.coef_
c,m
# Out:
# (array([-12636.5783771]),
#  array([[ 8.10139337e-03, -2.26771910e-01, -4.44209435e+00,
#           1.12984878e+00,  2.30297847e+02,  8.01805979e+00]]))

# %% [markdown]
# - Above output giving in exponensial values: to convert into normal values we using below with statement

# %%
with np.printoptions(precision=3, suppress=True):
  print(m,c)
# Out:
# [[  0.008  -0.227  -4.442   1.13  230.298   8.018]] [-12636.578]

# %%
Realdf.columns
# Out:
# Index(['X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
coeffdf =  pd.DataFrame({'col':X.columns,'coeff':m[0]})
coeffdf
# Out:
#                                       col       coeff
# 0                     X1 transaction date    0.008101
# 1                            X2 house age   -0.226772
# 2  X3 distance to the nearest MRT station   -4.442094
# 3         X4 number of convenience stores    1.129849
# 4                             X5 latitude  230.297847
# 5                            X6 longitude    8.018060

# %% [markdown]
# - Inference from above output
#
# - X5 latitude column have high impact on price of house.
# - if X3 distance increases than house of price reduces due to negative slop
# - X1 transaction date is very low impact on price of house

# %%
coeffdf.sort_values('coeff').set_index('col').plot.barh()

# %% [markdown]
# - Prdecting for X_train to check how model learnt from given data

# %%
y_learntdf = lrmodel.predict(X_train1)
y_learntdf[:5]
# Out:
# array([[45.10021581],
#        [36.82867785],
#        [30.15531324],
#        [32.21093297],
#        [43.60649619]])

# %%
learndf = pd.DataFrame({'Actual':y_train[:,0],'Learnt':y_learntdf[:,0]})
learndf.head()
# Out:
#    Actual     Learnt
# 0    40.1  45.100216
# 1    30.9  36.828678
# 2    22.9  30.155313
# 3    28.6  32.210933
# 4    44.0  43.606496

# %% [markdown]
# - ploting bar graph to visuialaize actual and learnt values

# %%
learndf.head().plot(kind='bar')

# %% [markdown]
# # Inference from above Graph
# - As we including all the columns and converted distance to MRT station column from meter to Kilometer : Error has been increased.

# %% [markdown]
# # importing metrics from sklearn to check mean square error

# %% [markdown]
# - We are using metrics to check accuracy of our model.
# - Using mean square error we can check how difference between actual and predicted values.

# %%
from sklearn.metrics import mean_squared_error as mse

# %%
train_mse = mse(y_train,y_learntdf)
train_mse
# Out:
# 67.21018854523585

# %%
rmse_train = np.sqrt(train_mse)
rmse_train
# Out:
# 8.198182026842039

# %% [markdown]
# - As per above result we have 67.24 training mean square error.
# - rmse is root mean square

# %% [markdown]
# - predicting for test data set

# %%
testdf = lrmodel.predict(X_test1)
testdf[:5]
# Out:
# array([[39.45841839],
#        [51.1380725 ],
#        [32.7468609 ],
#        [41.8478586 ],
#        [41.20740955]])

# %%
test = pd.DataFrame({'Actual':y_test[:,0],'Pred':testdf[:,0]})
test.head()
# Out:
#    Actual       Pred
# 0    32.9  39.458418
# 1    55.9  51.138073
# 2    25.3  32.746861
# 3    39.7  41.847859
# 4   117.5  41.207410

# %%
test_mse = mse(y_test,testdf)
test_mse
# Out:
# 112.2537237942389

# %%
rmse_test = np.sqrt(test_mse)
rmse_test
# Out:
# 10.59498578546658

# %% [markdown]
# - Above values shows that total difference between actual and predicted values for test dataset is 112 - erorr

# %% [markdown]
# # R2 score

# %%
from sklearn.metrics import r2_score

# %%
r2_real = r2_score(y_test,testdf)
r2_real
# Out:
# 0.47164135409645147

# %% [markdown]
# - R2 score will tell how much accurate and effecient your model is.
# - From above values we can see that our model is 47% accurate results.

# %%
y_mean = Realdf['Y house price of unit area'].mean()**2
y_mean
# Out:
# 1442.4950782982105

# %%
n= X.shape[0]
k= X.shape[1]
n,k
# Out:
# (414, 6)

# %%
Adj_R2 = 1-(((1-r2_real)*(n-1))/(n-k-1))
Adj_R2
# Out:
# 0.46385228314947036

# %% [markdown]
# - As we included 6 columns in the dataset and r2 score is 47%
# - our Adjusted R2 score is 46%
