# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %%
df.shape
# Out:
# (344, 7)

# %%
target = 'species'
X=df.drop(target,axis=1)
y=df.loc[:,target]

# %%
y.isna().sum()
# Out:
# 0

# %% [markdown]
# #Select Numerical and categorical columns

# %%
from sklearn.compose import make_column_selector

# %%
num_col = make_column_selector(dtype_exclude=object)
cat_col = make_column_selector(dtype_include=object)

# %% [markdown]
# #Impute Missing values

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline

# %%
imp_mean = SimpleImputer(strategy='mean')

# %%
imp_cat = SimpleImputer(strategy='most_frequent')
onehot = OneHotEncoder()

# %%
col_transform = make_column_transformer(
    #(make_pipeline(imp_mean,mm_scaler),num_col), --- this is for applying scaling only for numericals
    (make_pipeline(imp_mean),num_col),
    (make_pipeline(imp_cat,onehot),cat_col),
    remainder='passthrough'
)

# %% [markdown]
# # Build Model

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
std_scaler = StandardScaler()

# %%
mm_scaler = MinMaxScaler()

# %%
knn_model = KNeighborsClassifier()

# %%
pipe = make_pipeline(col_transform,std_scaler,knn_model)

# %%
from sklearn.model_selection import KFold

# %%
K_fold = KFold(n_splits=10,shuffle=True,random_state=985)

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(pipe,X,y,cv=K_fold)
# Out:
# array([0.97142857, 1.        , 1.        , 1.        , 1.        ,
#        1.        , 1.        , 0.97058824, 1.        , 0.94117647])

# %%
cross_val_score(pipe,X,y,cv=K_fold).mean()
# Out:
# 0.9883193277310924

# %%
from sklearn.model_selection import GridSearchCV

# %%
pipe.get_params()
# Out:
# {'columntransformer': ColumnTransformer(remainder='passthrough',
#                    transformers=[('pipeline-1',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer())]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f5aef639650>),
#                                  ('pipeline-2',
#                                   Pipeline(steps=[('simpleimputer',
#                                                    SimpleImputer(strategy='most_frequent')),
#                                                   ('onehotencoder',
#                                                    OneHotEncoder())]),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f5aef639610>)]),
#  'columntransformer__n_jobs': None,
#  'columntransformer__pipeline-1': Pipeline(steps=[('simpleimputer', SimpleImputer())]),
#  'columntransformer__pipeline-1__memory': None,
#  'columntransformer__pipeline-1__simpleimputer': SimpleImputer(),
#  'columntransformer__pipeline-1__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline-1__simpleimputer__copy': True,
#  'columntransformer__pipeline-1__simpleimputer__fill_value': None,
#  'columntransformer__pipeline-1__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline-1__simpleimputer__strategy': 'mean',
#  'columntransformer__pipeline-1__simpleimputer__verbose': 0,
#  'columntransformer__pipeline-1__steps': [('simpleimputer', SimpleImputer())],
#  'columntransformer__pipeline-1__verbose': False,
#  'columntransformer__pipeline-2': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('onehotencoder', OneHotEncoder())]),
#  'columntransformer__pipeline-2__memory': None,
#  'columntransformer__pipeline-2__onehotencoder': OneHotEncoder(),
#  'columntransformer__pipeline-2__onehotencoder__categories': 'auto',
#  'columntransformer__pipeline-2__onehotencoder__drop': None,
#  'columntransformer__pipeline-2__onehotencoder__dtype': numpy.float64,
#  'columntransformer__pipeline-2__onehotencoder__handle_unknown': 'error',
#  'columntransformer__pipeline-2__onehotencoder__sparse': True,
#  'columntransformer__pipeline-2__simpleimputer': SimpleImputer(strategy='most_frequent'),
#  'columntransformer__pipeline-2__simpleimputer__add_indicator': False,
#  'columntransformer__pipeline-2__simpleimputer__copy': True,
#  'columntransformer__pipeline-2__simpleimputer__fill_value': None,
#  'columntransformer__pipeline-2__simpleimputer__missing_values': nan,
#  'columntransformer__pipeline-2__simpleimputer__strategy': 'most_frequent',
#  'columntransformer__pipeline-2__simpleimputer__verbose': 0,
#  'columntransformer__pipeline-2__steps': [('simpleimputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('onehotencoder', OneHotEncoder())],
#  'columntransformer__pipeline-2__verbose': False,
#  'columntransformer__remainder': 'passthrough',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('pipeline-1',
#    Pipeline(steps=[('simpleimputer', SimpleImputer())]),
#    <sklearn.compose._column_transformer.make_column_selector at 0x7f5aef639650>),
#   ('pipeline-2',
#    Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                    ('onehotencoder', OneHotEncoder())]),
#    <sklearn.compose._column_transformer.make_column_selector at 0x7f5aef639610>)],
#  'columntransformer__verbose': False,
#  'columntransformer__verbose_feature_names_out': True,
#  'kneighborsclassifier': KNeighborsClassifier(),
#  'kneighborsclassifier__algorithm': 'auto',
#  'kneighborsclassifier__leaf_size': 30,
#  'kneighborsclassifier__metric': 'minkowski',
#  'kneighborsclassifier__metric_params': None,
#  'kneighborsclassifier__n_jobs': None,
#  'kneighborsclassifier__n_neighbors': 5,
#  'kneighborsclassifier__p': 2,
#  'kneighborsclassifier__weights': 'uniform',
#  'memory': None,
#  'standardscaler': StandardScaler(),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'steps': [('columntransformer', ColumnTransformer(remainder='passthrough',
#                      transformers=[('pipeline-1',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer())]),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x7f5aef639650>),
#                                    ('pipeline-2',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('onehotencoder',
#                                                      OneHotEncoder())]),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x7f5aef639610>)])),
#   ('standardscaler', StandardScaler()),
#   ('kneighborsclassifier', KNeighborsClassifier())],
#  'verbose': False}

# %%
params1 = {'columntransformer__pipeline-1__simpleimputer__strategy':  ['mean','median'],
           'standardscaler':[std_scaler,mm_scaler],
          'kneighborsclassifier__n_neighbors': range(2,30),
          'kneighborsclassifier__p': [1,2,3]
          }

# %%
grdcv1 = GridSearchCV(pipe,param_grid=params1,cv=K_fold,n_jobs=-1)

# %%
grdcv1.fit(X,y)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=985, shuffle=True),
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer())]),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x7f5aef639650>),
#                                                                         ('pipeline-2',
#                                                                          Pipeline(steps=[('si...
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x7f5aef639610>)])),
#                                        ('standardscaler', StandardScaler()),
#                                        ('kneighborsclassifier',
#                                         KNeighborsClassifier())]),
#              n_jobs=-1,
#              param_grid={'columntransformer__pipeline-1__simpleimputer__strategy': ['mean',
#                                                                                     'median'],
#                          'kneighborsclassifier__n_neighbors': range(2, 30),
#                          'kneighborsclassifier__p': [1, 2, 3],
#                          'standardscaler': [StandardScaler(), MinMaxScaler()]})

# %%
grd_df1= pd.DataFrame(grdcv1.cv_results_)
grd_df1
# Out:
#      mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0         0.023251      0.007240  ...        0.014205              285
# 1         0.021577      0.006989  ...        0.014205              285
# 2         0.028443      0.009363  ...        0.014205              285
# 3         0.021881      0.003207  ...        0.014205              285
# 4         0.023697      0.010955  ...        0.014205              285
# ..             ...           ...  ...             ...              ...
# 331       0.019508      0.001327  ...        0.011598                1
# 332       0.027887      0.009071  ...        0.013352              145
# 333       0.019605      0.001017  ...        0.011598                1
# 334       0.020489      0.002287  ...        0.013352              145
# 335       0.020553      0.002045  ...        0.011598                1
#
# [336 rows x 22 columns]

# %%
grd_df1[['params','mean_test_score','rank_test_score']].sort_values('rank_test_score').head()
# Out:
#                                                 params  ...  rank_test_score
# 167  {'columntransformer__pipeline-1__simpleimputer...  ...                1
# 187  {'columntransformer__pipeline-1__simpleimputer...  ...                1
# 204  {'columntransformer__pipeline-1__simpleimputer...  ...                1
# 205  {'columntransformer__pipeline-1__simpleimputer...  ...                1
# 206  {'columntransformer__pipeline-1__simpleimputer...  ...                1
#
# [5 rows x 3 columns]

# %%
grdcv1.best_score_
# Out:
# 0.9942016806722689

# %%
grdcv1.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'mean',
#  'kneighborsclassifier__n_neighbors': 3,
#  'kneighborsclassifier__p': 3,
#  'standardscaler': StandardScaler()}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rmdcv = RandomizedSearchCV(pipe,params1,n_iter=40,random_state=895,n_jobs=-1,cv=K_fold)

# %%
rmdcv.fit(X,y)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=10, random_state=985, shuffle=True),
#                    estimator=Pipeline(steps=[('columntransformer',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('pipeline-1',
#                                                                                Pipeline(steps=[('simpleimputer',
#                                                                                                 SimpleImputer())]),
#                                                                                <sklearn.compose._column_transformer.make_column_selector object at 0x7f5aef639650>),
#                                                                               ('pipeline-2',
#                                                                                Pipeline(steps...
#                                              ('standardscaler',
#                                               StandardScaler()),
#                                              ('kneighborsclassifier',
#                                               KNeighborsClassifier())]),
#                    n_iter=40, n_jobs=-1,
#                    param_distributions={'columntransformer__pipeline-1__simpleimputer__strategy': ['mean',
#                                                                                                    'median'],
#                                         'kneighborsclassifier__n_neighbors': range(2, 30),
#                                         'kneighborsclassifier__p': [1, 2, 3],
#                                         'standardscaler': [StandardScaler(),
#                                                            MinMaxScaler()]},
#                    random_state=895)

# %%
rmdcv.best_score_
# Out:
# 0.9942016806722689

# %%
rmdcv.best_params_
# Out:
# {'columntransformer__pipeline-1__simpleimputer__strategy': 'median',
#  'kneighborsclassifier__n_neighbors': 24,
#  'kneighborsclassifier__p': 2,
#  'standardscaler': MinMaxScaler()}

# %%
best = rmdcv.best_estimator_
best
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f5aea0f2dd0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f5aea0f2090>)])),
#                 ('standardscaler', MinMaxScaler()),
#                 ('kneighborsclassifier', KNeighborsClassifier(n_neighbors=24))])

# %%
col_transform.fit_transform(X,y)
# Out:
# array([[ 39.1,  18.7, 181. , ...,   1. ,   0. ,   1. ],
#        [ 39.5,  17.4, 186. , ...,   1. ,   1. ,   0. ],
#        [ 40.3,  18. , 195. , ...,   1. ,   1. ,   0. ],
#        ...,
#        [ 50.4,  15.7, 222. , ...,   0. ,   0. ,   1. ],
#        [ 45.2,  14.8, 212. , ...,   0. ,   1. ,   0. ],
#        [ 49.9,  16.1, 213. , ...,   0. ,   0. ,   1. ]])

# %%
col_transform
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f5aef639650>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f5aef639610>)])

# %%
col_transform.transformers_[0]
# Out:
# ('pipeline-1',
#  Pipeline(steps=[('simpleimputer', SimpleImputer())]),
#  ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g'])

# %%
col_transform.transformers_[0][1]
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer())])

# %%
col_transform.transformers_[0][1].fit_transform(X[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']],y)
# Out:
# array([[  39.1,   18.7,  181. , 3750. ],
#        [  39.5,   17.4,  186. , 3800. ],
#        [  40.3,   18. ,  195. , 3250. ],
#        ...,
#        [  50.4,   15.7,  222. , 5750. ],
#        [  45.2,   14.8,  212. , 5200. ],
#        [  49.9,   16.1,  213. , 5400. ]])

# %%
X_trans = col_transform.fit_transform(X,y)
X_trans
# Out:
# array([[ 39.1,  18.7, 181. , ...,   1. ,   0. ,   1. ],
#        [ 39.5,  17.4, 186. , ...,   1. ,   1. ,   0. ],
#        [ 40.3,  18. , 195. , ...,   1. ,   1. ,   0. ],
#        ...,
#        [ 50.4,  15.7, 222. , ...,   0. ,   0. ,   1. ],
#        [ 45.2,  14.8, 212. , ...,   0. ,   1. ,   0. ],
#        [ 49.9,  16.1, 213. , ...,   0. ,   0. ,   1. ]])

# %%
col_transform.transformers_[1]
# Out:
# ('pipeline-2',
#  Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('onehotencoder', OneHotEncoder())]),
#  ['island', 'sex'])

# %%
col_transform.transformers_[1][1]
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehotencoder', OneHotEncoder())])

# %%
col_transform.transformers_[1][1][1]
# Out:
# OneHotEncoder()

# %%
col_transform.transformers_[1][1][1].get_feature_names_out()
# Out:
# array(['x0_Biscoe', 'x0_Dream', 'x0_Torgersen', 'x1_Female', 'x1_Male'],
#       dtype=object)
