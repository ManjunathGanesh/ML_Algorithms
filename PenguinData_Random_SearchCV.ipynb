# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Importing Penguin Cleaned data set from git hub account

# %%
penguin = pd.read_csv("https://raw.githubusercontent.com/Manju410/MLPractice/main/data/Penguin.csv")
penguin.head()
# Out:
#    species  island  bill_length_mm  ...  flipper_length_mm  body_mass_g  sex
# 0        0       0        0.254545  ...           0.152542     0.291667    0
# 1        0       0        0.269091  ...           0.237288     0.305556    1
# 2        0       0        0.298182  ...           0.389831     0.152778    1
# 3        0       0        0.429888  ...           0.490088     0.417154    0
# 4        0       0        0.167273  ...           0.355932     0.208333    1
#
# [5 rows x 7 columns]

# %% [markdown]
# # Rows and Columns of penguin data set

# %%
penguin.shape
# Out:
# (344, 7)

# %% [markdown]
# # Checking Null values in penguin data set

# %%
penguin.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# # Independent and dependent variables of penguin data set

# %%
X = penguin.drop("species",axis=1)
y = penguin.species

# %%
X.shape,y.shape
# Out:
# ((344, 6), (344,))

# %% [markdown]
# # KNN Classifier Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_classifier = KNeighborsClassifier()

# %%
knn_classifier
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
knn_classifier?

# %%
param_grid = {"n_neighbors":range(2,30),
              "p":[1,2,3]}

# %% [markdown]
# # Random SearchCv to find best parameter from model

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
grid_model = RandomizedSearchCV(knn_classifier,param_grid,scoring='accuracy',cv=10,n_iter=15)

# %%
grid_model.fit(X,y)
# Out:
# RandomizedSearchCV(cv=10, error_score=nan,
#                    estimator=KNeighborsClassifier(algorithm='auto',
#                                                   leaf_size=30,
#                                                   metric='minkowski',
#                                                   metric_params=None,
#                                                   n_jobs=None, n_neighbors=5,
#                                                   p=2, weights='uniform'),
#                    iid='deprecated', n_iter=15, n_jobs=None,
#                    param_distributions={'n_neighbors': range(2, 30),
#                                         'p': [1, 2, 3]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='accuracy', verbose=0)

# %% [markdown]
# # grid model contain n_neighbors from range 2 to 30 with k fold cv=10

# %%
df_grid = pd.DataFrame(grid_model.cv_results_)
df_grid.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_p', 'param_n_neighbors', 'params', 'split0_test_score',
#        'split1_test_score', 'split2_test_score', 'split3_test_score',
#        'split4_test_score', 'split5_test_score', 'split6_test_score',
#        'split7_test_score', 'split8_test_score', 'split9_test_score',
#        'mean_test_score', 'std_test_score', 'rank_test_score'],
#       dtype='object')

# %%
df_grid[['rank_test_score','params','mean_test_score','std_test_score']].sort_values('rank_test_score')
# Out:
#     rank_test_score  ... std_test_score
# 11                1  ...       0.011598
# 3                 2  ...       0.011765
# 1                 3  ...       0.013352
# 4                 3  ...       0.013352
# 6                 3  ...       0.013352
# 7                 3  ...       0.013352
# 8                 3  ...       0.013352
# 10                3  ...       0.013352
# 12                3  ...       0.013352
# 14                3  ...       0.013352
# 0                11  ...       0.019107
# 2                11  ...       0.019107
# 5                11  ...       0.019107
# 9                11  ...       0.019107
# 13               15  ...       0.019435
#
# [15 rows x 4 columns]

# %%
grid_model.best_score_
# Out:
# 0.9814524382766144

# %%
grid_model.best_params_
# Out:
# {'n_neighbors': 5, 'p': 1}

# %%
grid_model.best_estimator_
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#                      weights='uniform')

# %% [markdown]
# # From above grid search model we found n_neighbors=5 and p=1 (Manhattan distance) to fit best KNN clasifier model
