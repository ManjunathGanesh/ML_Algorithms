# %%
import numpy as np

# %%
p1=np.array([1.2,23.5,45,2])
p2=np.array([5,29.1,42.5,1.2])

# %%
p = p1-p2

# %%
abs(p)
# Out:
# array([3.8, 5.6, 2.5, 0.8])

# %%
np.abs(p).sum()
# Out:
# 12.700000000000003

# %%
np.abs(p1-p2).sum()
# Out:
# 12.700000000000003

# %% [markdown]
# # Eucledian distance

# %%
p1=np.array([10,5])
p2=np.array([1,20])

# %%
p = np.sqrt((p1-p2)**2)
p
# Out:
# array([ 9., 15.])

# %%
p1-p2
# Out:
# array([  9, -15])

# %%
(p1-p2)**2
# Out:
# array([ 81, 225])

# %%
((p1-p2)**2).sum()
# Out:
# 306

# %%
np.sqrt(((p1-p2)**2).sum())
# Out:
# 17.4928556845359

# %%
p1=np.array([2,5])
p2=np.array([8,4])

# %%
np.abs(p1-p2).sum()
# Out:
# 7

# %%
np.sqrt(((p1-p2)**2).sum())
# Out:
# 6.082762530298219

# %%
p1=np.array([1,4,10])
p2=np.array([5,2,7])

# %%
np.sqrt(((p1-p2)**2).sum())
# Out:
# 5.385164807134504

# %%
np.abs(p1-p2).sum()
# Out:
# 9

# %%
p1=np.array([1.2,23.5,45,2])
p2=np.array([5,29.1,42.5,1.2])

# %%
np.abs(p1-p2).sum()
# Out:
# 12.700000000000003

# %%
np.sqrt(((p1-p2)**2).sum())
# Out:
# 7.258787777583804

# %%
(((p1-p2)**2).sum())**(1/2)
# Out:
# 7.258787777583804

# %% [markdown]
# #Minkowiski

# %%
(((p1-p2)**3).sum())**(1/3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in double_scalars
#   """Entry point for launching an IPython kernel.
# nan

# %%
(p1-p2)**3
# Out:
# array([ -54.872, -175.616,   15.625,    0.512])

# %%
k=5
np.abs(((p1-p2)**k).sum())**(1/k)
# Out:
# 5.734584385424231

# %% [markdown]
# # Penguin Example

# %%
p1=np.array([191,4600])
p2=np.array([218,4400])
p3=np.array([217,5000])

# %%
k=2
np.abs(((p1-p2)**k).sum())**(1/k)
# Out:
# 201.8142710513803

# %%
np.abs(p1-p2).sum()
# Out:
# 227

# %%
np.abs(p1-p3).sum()
# Out:
# 426

# %%
np.abs(p2-p3).sum()
# Out:
# 601

# %%
p1=np.array([191,460])
p2=np.array([218,440])
p3=np.array([217,500])

# %%
np.abs(p1-p2).sum()
# Out:
# 47

# %%
np.abs(p1-p3).sum()
# Out:
# 66

# %%
np.abs(p2-p3).sum()
# Out:
# 61

# %%
p1=np.array([0.322,0.527])
p2=np.array([0.779,0.472])
p3=np.array([0.762,0.639])

# %%
np.abs(p1-p2).sum()
# Out:
# 0.512

# %%
np.abs(p1-p3).sum()
# Out:
# 0.552

# %%
np.abs(p2-p3).sum()
# Out:
# 0.18400000000000005
