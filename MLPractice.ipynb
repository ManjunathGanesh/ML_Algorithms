# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Manju410/MLPractice/main/data/Cardetails.csv')
df.head()
# Out:
#                            name  year  ...                    torque  seats
# 0        Maruti Swift Dzire VDI  2014  ...            190Nm@ 2000rpm    5.0
# 1  Skoda Rapid 1.5 TDI Ambition  2014  ...       250Nm@ 1500-2500rpm    5.0
# 2      Honda City 2017-2020 EXi  2006  ...     12.7@ 2,700(kgm@ rpm)    5.0
# 3     Hyundai i20 Sportz Diesel  2010  ...  22.4 kgm at 1750-2750rpm    5.0
# 4        Maruti Swift VXI BSIII  2007  ...     11.5@ 4,500(kgm@ rpm)    5.0
#
# [5 rows x 13 columns]

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Outlier Treatment

# %%
sample= np.array([15, 101, 18, 7, 13, 16, 11, 21, 5, 15, 10, 9])
sample
# Out:
# array([ 15, 101,  18,   7,  13,  16,  11,  21,   5,  15,  10,   9])

# %%
tenth_percentile = np.percentile(sample, 10)
tenth_percentile
# Out:
# 7.199999999999999

# %%
len(sample)
# Out:
# 12

# %%
sml = sample[sample<tenth_percentile]
sml
# Out:
# array([7, 5])

# %%
sorted(sample)
# Out:
# [5, 7, 9, 10, 11, 13, 15, 15, 16, 18, 21, 101]

# %%
ninetieth_percentile = np.percentile(sample, 90)
ninetieth_percentile
# Out:
# 20.7

# %%
sml1 = sample[sample>ninetieth_percentile]
sml1
# Out:
# array([101,  21])

# %%
sorted(sample)
# Out:
# [5, 7, 9, 10, 11, 13, 15, 15, 16, 18, 21, 101]

# %%
b = np.where(sample<tenth_percentile, tenth_percentile, sample)
sorted(b)
# Out:
# [7.199999999999999,
#  7.199999999999999,
#  9.0,
#  10.0,
#  11.0,
#  13.0,
#  15.0,
#  15.0,
#  16.0,
#  18.0,
#  21.0,
#  101.0]

# %%
b = np.where(b>ninetieth_percentile, ninetieth_percentile, b)
sorted(b)
# Out:
# [7.199999999999999,
#  7.199999999999999,
#  9.0,
#  10.0,
#  11.0,
#  13.0,
#  15.0,
#  15.0,
#  16.0,
#  18.0,
#  20.7,
#  20.7]

# %%
3/1.57
# Out:
# 1.910828025477707

# %%
62.99-(2*1.57)
# Out:
# 59.85

# %%
1.57*2
# Out:
# 3.14

# %%
62.99+(2*1.57)
# Out:
# 66.13

# %%
(66.13-59.85)/2
# Out:
# 3.139999999999997

# %%
62.99-(1.96*1.57)
# Out:
# 59.912800000000004

# %%
62.99+(1.96*1.57)
# Out:
# 66.0672

# %%
(66-60)/2
# Out:
# 3.0

# %%
captains_url = "https://raw.githubusercontent.com/asarfraaz/PyPractice/master/data/captains.txt"

# %%
captains_url
# Out:
# 'https://raw.githubusercontent.com/asarfraaz/PyPractice/master/data/captains.txt'

# %%
df= pd.read_csv(captains_url)

# %%
df
# Out:
#                Player       Span  Mat  Won  Lost  Tied  NR       %
# 0   S Venkataraghavan  1975-1979    7    1     6     0   0   14.28
# 1             BS Bedi  1976-1978    4    1     3     0   0   25.00
# 2          AL Wadekar  1974-1974    2    0     2     0   0    0.00
# 3         SM Gavaskar  1980-1985   37   14    21     0   2   40.00
# 4        GR Viswanath  1981-1981    1    0     1     0   0    0.00
# 5         N Kapil Dev  1982-1987   74   39    33     0   2   54.16
# 6         SMH Kirmani  1983-1983    1    0     1     0   0    0.00
# 7          M Amarnath  1984-1984    1    0     0     0   1       -
# 8       DB Vengsarkar  1987-1989   18    8    10     0   0   44.44
# 9          RJ Shastri  1987-1991   11    4     7     0   0   36.36
# 10        K Srikkanth  1989-1989   13    4     8     0   1   33.33
# 11       M Azharuddin  1990-1999  174   90    76     2   6   54.16
# 12       SR Tendulkar  1996-2000   73   23    43     1   6   35.07
# ...

# %%
freinds=["Jhon","Kennedy","Marry","Suby"]

# %%
df[["Player","Mat"]].head()
# Out:
#               Player  Mat
# 0  S Venkataraghavan    7
# 1            BS Bedi    4
# 2         AL Wadekar    2
# 3        SM Gavaskar   37
# 4       GR Viswanath    1

# %%
df[['Player','Mat']].sort_values('Mat',ascending=False).head()
# Out:
#           Player  Mat
# 18      MS Dhoni  199
# 11  M Azharuddin  174
# 14    SC Ganguly  146
# 15      R Dravid   79
# 5    N Kapil Dev   74

# %% [markdown]
# # New Section

# %%
freinds[0]
# Out:
# 'Jhon'

# %%
type(freinds[0])
# Out:
# str

# %%
freinds[:2]
# Out:
# ['Jhon', 'Kennedy']

# %%
type(freinds[:2])
# Out:
# list

# %%
import numpy as np

# %%
rng= np.random.default_rng(100)

# %%
rng.random()
# Out:
# 0.8349816305020089

# %%
rng.random()
# Out:
# 0.5965540269678873

# %%
rng.random()
# Out:
# 0.2888632416912036

# %%
rng.choice(['H','T'])
# Out:
# 'H'

# %%
rng.choice(['H','T'])
# Out:
# 'H'

# %%
[rng.choice(['H','T']) for _ in range(10)]
# Out:
# ['T', 'T', 'T', 'H', 'T', 'T', 'T', 'H', 'T', 'T']

# %%
values=rng.choice(['H','T'], size=5)

# %%
values
# Out:
# array(['H', 'T', 'T', 'T', 'H'], dtype='<U1')

# %%
values=='H'
# Out:
# array([ True, False, False, False,  True])

# %%
sum(values=='H')
# Out:
# 2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
heads=list()
for _ in range(5000):
  values=rng.choice(['H','T'], size=5)
  count= sum(values=='H')
  heads.append(count)

# %%
heads[:10]
# Out:
# [2, 3, 3, 4, 4, 3, 0, 2, 2, 1]

# %%
vals,freq=np.unique(heads, return_counts=True)

# %%
plt.bar(vals,freq,align="center")
# Out:
# <BarContainer object of 6 artists>

# %%
heads_sim= rng.binomial(n=5,p=0.5,size=10_000)
heads_sim[:10]
# Out:
# array([2, 4, 5, 2, 5, 4, 2, 4, 4, 3])

# %%
vals,freq=np.unique(heads_sim, return_counts=True)
plt.bar(vals, freq)
# Out:
# <BarContainer object of 6 artists>

# %%
norm= freq/10_000
norm
# Out:
# array([0.0288, 0.1542, 0.3139, 0.3142, 0.1529, 0.036 ])

# %%
plt.bar(vals, norm)
# Out:
# <BarContainer object of 6 artists>

# %%
sum(heads_sim==3)/10_000
# Out:
# 0.3142

# %%
heads_sim[:10]
# Out:
# array([2, 4, 5, 2, 5, 4, 2, 4, 4, 3])

# %%
sum(heads_sim[:10]>=3)
# Out:
# 7

# %%
sum(heads_sim>=3)/10_000
# Out:
# 0.5031

# %%
norm
# Out:
# array([0.0288, 0.1542, 0.3139, 0.3142, 0.1529, 0.036 ])

# %%
sum(norm[3:])
# Out:
# 0.5031

# %%
red_Prob= 4/7
red_Prob
# Out:
# 0.5714285714285714

# %%
red= rng.binomial(n=5,p=red_Prob,size=10_000)
red[:10]
# Out:
# array([3, 2, 2, 3, 2, 5, 2, 1, 5, 4])

# %%
vals,freq=np.unique(red, return_counts=True)
plt.bar(vals, freq)
# Out:
# <BarContainer object of 6 artists>

# %%
norms= freq/10_000

# %%
norms
# Out:
# array([0.0143, 0.0981, 0.2554, 0.3454, 0.2274, 0.0594])

# %%
red= rng.binomial(n=9,p=0.1,size=10_000)
red[:10]
# Out:
# array([2, 0, 3, 1, 1, 3, 1, 3, 0, 1])

# %%
vals,freq=np.unique(red, return_counts=True)
plt.bar(vals, freq)
# Out:
# <BarContainer object of 7 artists>

# %%
norms= freq/10_000

# %%
norms[0]
# Out:
# 0.3795

# %%
red= rng.binomial(n=30,p=0.06,size=10_000)
red[:10]
# Out:
# array([0, 1, 4, 3, 1, 2, 4, 2, 1, 3])

# %%
vals,freq=np.unique(red, return_counts=True)
plt.bar(vals, freq)
# Out:
# <BarContainer object of 10 artists>

# %%
red[:10]
# Out:
# array([0, 1, 4, 3, 1, 2, 4, 2, 1, 3])

# %%
len(red)
# Out:
# 10000

# %%
sum(red>=3)/10_000
# Out:
# 0.2644

# %%
norms= freq/10_000
[x.round(4) for x in norms]
# Out:
# [0.157, 0.3055, 0.2731, 0.1654, 0.0698, 0.0229, 0.005, 0.001, 0.0002, 0.0001]

# %%
norms
# Out:
# array([1.570e-01, 3.055e-01, 2.731e-01, 1.654e-01, 6.980e-02, 2.290e-02,
#        5.000e-03, 1.000e-03, 2.000e-04, 1.000e-04])

# %%
sum(norms[3:])
# Out:
# 0.26439999999999997

# %%
sns.countplot(red)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
red= rng.binomial(n=30,p=0.016,size=10_000)
red[:10]
# Out:
# array([0, 0, 0, 1, 0, 2, 0, 1, 0, 0])

# %%
vals,freq=np.unique(red, return_counts=True)
plt.bar(vals, freq)
# Out:
# <BarContainer object of 6 artists>

# %%
red[:10]
# Out:
# array([0, 0, 0, 1, 0, 2, 0, 1, 0, 0])

# %%
sum(red>=3)/10_000
# Out:
# 0.0118

# %%
rng= np.random.default_rng(100)

# %%
throws= rng.uniform(0,6,size=10_000)

# %%
throws[:10]
# Out:
# array([3.20325685, 5.93876026, 2.54156886, 1.66695087, 3.39901085,
#        4.9115757 , 3.36534503, 5.05347137, 4.01334496, 3.78296046])

# %%
ceils=np.ceil(throws)

# %%
ar= np.array([0.9,1.5,1.9,2.2,2.9])

# %%
np.round(ar)
# Out:
# array([1., 2., 2., 2., 3.])

# %%
vals, freq= np.unique(ceils, return_counts=True)

# %%
vals
# Out:
# array([1., 2., 3., 4., 5., 6.])

# %%
freq
# Out:
# array([1695, 1683, 1675, 1651, 1697, 1599])

# %%
np.mean(freq)
# Out:
# 1666.6666666666667

# %%
sns.countplot(ceils)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(x=vals,y=freq)

# %%
throws= rng.integers(1,6,endpoint=True,size=100_000)

# %%
np.unique(throws)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
vals,freq= np.unique(throws,return_counts=True)
vals
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
freq
# Out:
# array([16608, 16738, 16624, 16740, 16769, 16521])

# %%
np.mean(freq)
# Out:
# 16666.666666666668

# %%
sns.countplot(throws)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
runs={"0": 46,"1":38,"2":12,"3":0,"4":15,"5":0,"6":9}

# %%
vals=np.array(list(runs.keys()))
vals
# Out:
# array(['0', '1', '2', '3', '4', '5', '6'], dtype='<U1')

# %%
freq=np.array(list(runs.values()))
freq
# Out:
# array([46, 38, 12,  0, 15,  0,  9])

# %%
prob=freq/sum(freq)

# %%
prob
# Out:
# array([0.38333333, 0.31666667, 0.1       , 0.        , 0.125     ,
#        0.        , 0.075     ])

# %%
probs=np.round(prob,decimals=2)
probs
# Out:
# array([0.38, 0.32, 0.1 , 0.  , 0.12, 0.  , 0.08])

# %%
newdict= dict(zip(vals,probs))

# %%
newdict
# Out:
# {'0': 0.38, '1': 0.32, '2': 0.1, '3': 0.0, '4': 0.12, '5': 0.0, '6': 0.08}

# %%
rng.choice(vals,size=12)
# Out:
# array(['6', '4', '6', '4', '4', '4', '2', '2', '4', '1', '4', '1'],
#       dtype='<U1')

# %%
rng.choice(vals,size=12,p=probs)
# Out:
# array(['4', '4', '0', '4', '1', '1', '1', '2', '1', '0', '0', '1'],
#       dtype='<U1')

# %%
mum= rng.choice(vals,size=120,p=probs)

# %%
np.unique(mum,return_counts=True)
# Out:
# (array(['0', '1', '2', '4', '6'], dtype='<U1'), array([41, 31, 16, 20, 12]))

# %%
sum(map(int,mum))
# Out:
# 215

# %%
rcb=rng.choice(vals,size=120,p=probs)

# %%
np.unique(rcb,return_counts=True)
# Out:
# (array(['0', '1', '2', '4', '6'], dtype='<U1'), array([46, 35, 15, 16,  8]))

# %%
sum(map(int,rcb))
# Out:
# 177

# %%
indmean=165
indsd=20

# %%
indhgts= rng.normal(loc=indmean,scale=indsd,size=100000)

# %%
indhgts[:10]
# Out:
# array([151.53369514, 187.284069  , 196.6886571 , 170.48073816,
#        155.32892729, 172.58825232, 167.10913593, 144.8272388 ,
#        172.21776871, 182.51168929])

# %%
indhgts.mean()
# Out:
# 165.077679121437

# %%
indhgts.std()
# Out:
# 19.976285362920056

# %%
np.median(indhgts)
# Out:
# 165.08169510203112

# %%
left= indhgts.mean()-(3*indhgts.std())
left
# Out:
# 105.14882303267683

# %%
right= indhgts.mean()+(3*indhgts.std())
right
# Out:
# 225.00653521019717

# %%
len(indhgts)
# Out:
# 100000

# %%
sum((indhgts>left) & (indhgts<right))
# Out:
# 99725

# %%
sum((indhgts>left) & (indhgts<right))/len(indhgts)
# Out:
# 0.99725

# %%
ushgts= rng.normal(loc=177,scale=30,size=100000)

# %%
leftus= ushgts.mean()-(3*ushgts.std())
leftus
# Out:
# 86.89524452868783

# %%
rightus =ushgts.mean()+(3*ushgts.std())
rightus
# Out:
# 267.04210680804084

# %%
sum((ushgts>leftus) & (ushgts<rightus))
# Out:
# 99734

# %%
sum((ushgts>leftus) & (ushgts<rightus))/len(ushgts)
# Out:
# 0.99734

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/asarfraaz/PyPractice/master/data/Test_Cricket_Players.csv")

# %%
df
# Out:
#      Unnamed: 0          Name Runs  ...   Start Date  Unnamed: 15 Result
# 0           NaN      MS Dhoni   30  ...   2 Dec 2005  Test # 1775   Lost
# 1           NaN      MS Dhoni    5  ...  10 Dec 2005  Test # 1776    Won
# 2           NaN      MS Dhoni  51*  ...  10 Dec 2005  Test # 1776    Won
# 3           NaN      MS Dhoni   49  ...  18 Dec 2005  Test # 1778    Won
# 4           NaN      MS Dhoni   14  ...  18 Dec 2005  Test # 1778    Won
# ..          ...           ...  ...  ...          ...          ...    ...
# 447         NaN  Rohit Sharma  127  ...   2 Oct 2019  Test # 2363    Won
# 448         NaN  Rohit Sharma   14  ...  10 Oct 2019  Test # 2364    Won
# 449         NaN  Rohit Sharma  212  ...  19 Oct 2019  Test # 2365    Won
# 450         NaN  Rohit Sharma    6  ...  14 Nov 2019  Test # 2366    Won
# 451         NaN  Rohit Sharma   21  ...  22 Nov 2019  Test # 2369    Won
#
# [452 rows x 17 columns]

# %%
df.to_csv("C:\Manjunath\Personal\new.csv") # to write csv

# %%
((2.9*2.9)/15)+((2.1*2.1)/15)
# Out:
# 0.8546666666666667

# %%
0.6/np.sqrt(0.8546)
# Out:
# 0.6490375239271462

# %%
8.07/(np.sqrt(6))
# Out:
# 3.294563704043375

# %%
2.571*3.29
# Out:
# 8.458590000000001
